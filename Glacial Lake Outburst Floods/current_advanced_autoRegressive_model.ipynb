# %%
import pandas as pd

# %%
file_path='daily_means_added.csv'

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#        WS10M       PS  PRECTOTCORR  T2MDEW  ALLSKY_SFC_LW_DWN  WS50M_RANGE  \
# 0     3.1828  72.9256       0.3600 -4.1916           260.3304       5.5412
# 1     3.0600  73.0680       0.4344 -4.9544           255.7372       4.7592
# 2     2.9300  73.1084       0.1660 -3.1056           266.0684       4.7816
# 3     2.5656  73.2004       0.0000 -0.4264           284.4488       4.0272
# 4     2.6156  73.1484       0.0352  0.7880           288.2028       4.5400
# ...      ...      ...          ...     ...                ...          ...
# 1822  3.1768  73.3196       0.0000 -0.0044           293.8880       5.8884
# 1823  3.5756  73.2196       0.0472  1.5248           290.0232       6.1368
# 1824  3.7140  73.2296       0.9904  1.7996           290.6472       5.3376
# 1825  4.4760  73.2168       3.5760  1.1412           303.1752       7.0696
# 1826  3.7992  73.0996       0.1976 -2.2784           284.1808       6.5032
#
#       Evaporation_Rate  Sensible_Heat_Flux        date
# ...

# %%
print(data.isnull().sum())
# Out:
# WS10M                 0
# PS                    0
# PRECTOTCORR           0
# T2MDEW                0
# ALLSKY_SFC_LW_DWN     0
# WS50M_RANGE           0
# Evaporation_Rate      0
# Sensible_Heat_Flux    0
# date                  0
# dtype: int64

# %%
data['date'] = pd.to_datetime(data[['YEAR', 'MO', 'DY']].rename(columns={'YEAR':'year', 'MO':'month', 'DY':'day'})) # Rename columns to match expected names by to_datetime

# data.drop(['YEAR', 'MO', 'DY'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data['date'] = pd.to_datetime(data[['YEAR', 'MO', 'DY']].rename(columns={'YEAR':'year', 'MO':'month', 'DY':'day'})) # Rename columns to match expected names by to_datetime
#       3 # data.drop(['YEAR', 'MO', 'DY'], axis=1, inplace=True)
#
# File c:\Users\ayush\miniconda3\envs\py310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ayush\miniconda3\envs\py310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
# ...

# %%
data
# Out:
#        WS10M       PS  PRECTOTCORR  T2MDEW  ALLSKY_SFC_LW_DWN  WS50M_RANGE  \
# 0     3.1828  72.9256       0.3600 -4.1916           260.3304       5.5412
# 1     3.0600  73.0680       0.4344 -4.9544           255.7372       4.7592
# 2     2.9300  73.1084       0.1660 -3.1056           266.0684       4.7816
# 3     2.5656  73.2004       0.0000 -0.4264           284.4488       4.0272
# 4     2.6156  73.1484       0.0352  0.7880           288.2028       4.5400
# ...      ...      ...          ...     ...                ...          ...
# 1822  3.1768  73.3196       0.0000 -0.0044           293.8880       5.8884
# 1823  3.5756  73.2196       0.0472  1.5248           290.0232       6.1368
# 1824  3.7140  73.2296       0.9904  1.7996           290.6472       5.3376
# 1825  4.4760  73.2168       3.5760  1.1412           303.1752       7.0696
# 1826  3.7992  73.0996       0.1976 -2.2784           284.1808       6.5032
#
#       Evaporation_Rate  Sensible_Heat_Flux        date
# ...

# %%
data = data.drop(columns=['LAT', 'LON'])

# %%
data
# Out:
#        WS10M       PS  PRECTOTCORR  T2MDEW  ALLSKY_SFC_LW_DWN  WS50M_RANGE  \
# 0     3.1828  72.9256       0.3600 -4.1916           260.3304       5.5412
# 1     3.0600  73.0680       0.4344 -4.9544           255.7372       4.7592
# 2     2.9300  73.1084       0.1660 -3.1056           266.0684       4.7816
# 3     2.5656  73.2004       0.0000 -0.4264           284.4488       4.0272
# 4     2.6156  73.1484       0.0352  0.7880           288.2028       4.5400
# ...      ...      ...          ...     ...                ...          ...
# 1822  3.1768  73.3196       0.0000 -0.0044           293.8880       5.8884
# 1823  3.5756  73.2196       0.0472  1.5248           290.0232       6.1368
# 1824  3.7140  73.2296       0.9904  1.7996           290.6472       5.3376
# 1825  4.4760  73.2168       3.5760  1.1412           303.1752       7.0696
# 1826  3.7992  73.0996       0.1976 -2.2784           284.1808       6.5032
#
#       Evaporation_Rate  Sensible_Heat_Flux        date
# ...

# %%
data.set_index('date', inplace=True)

# %%
data
# Out:
#              WS10M       PS  PRECTOTCORR  T2MDEW  ALLSKY_SFC_LW_DWN  \
# date
# 2019-04-01  3.1828  72.9256       0.3600 -4.1916           260.3304
# 2019-04-02  3.0600  73.0680       0.4344 -4.9544           255.7372
# 2019-04-03  2.9300  73.1084       0.1660 -3.1056           266.0684
# 2019-04-04  2.5656  73.2004       0.0000 -0.4264           284.4488
# 2019-04-05  2.6156  73.1484       0.0352  0.7880           288.2028
# ...            ...      ...          ...     ...                ...
# 2024-03-27  3.1768  73.3196       0.0000 -0.0044           293.8880
# 2024-03-28  3.5756  73.2196       0.0472  1.5248           290.0232
# 2024-03-29  3.7140  73.2296       0.9904  1.7996           290.6472
# 2024-03-30  4.4760  73.2168       3.5760  1.1412           303.1752
# 2024-03-31  3.7992  73.0996       0.1976 -2.2784           284.1808
#
#             WS50M_RANGE  Evaporation_Rate  Sensible_Heat_Flux
# date
# 2019-04-01       5.5412        259.819580           60.418107
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

columns_to_normalize = ['WS10M', 'PS', 'PRECTOTCORR', 'T2MDEW', 'ALLSKY_SFC_LW_DWN', 'WS50M_RANGE']

scaler = MinMaxScaler()

data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

print(data.head())
# Out:
#                WS10M        PS  PRECTOTCORR    T2MDEW  ALLSKY_SFC_LW_DWN  \
# date
# 2019-04-01  0.388678  0.567343     0.002445  0.427349           0.373572
# 2019-04-02  0.360281  0.659906     0.002950  0.403839           0.346300
# 2019-04-03  0.330219  0.686167     0.001127  0.460821           0.407640
# 2019-04-04  0.245953  0.745970     0.000000  0.543396           0.516771
# 2019-04-05  0.257515  0.712168     0.000239  0.580825           0.539059
#
#             WS50M_RANGE  Evaporation_Rate  Sensible_Heat_Flux
# date
# 2019-04-01     0.490933        259.819580           60.418107
# 2019-04-02     0.369933        255.209224           58.365991
# 2019-04-03     0.373399        265.582488           55.534465
# 2019-04-04     0.256669        284.012386           48.210601
# 2019-04-05     0.336015        287.793663           48.897510

# %%
df = pd.DataFrame(data, columns=['WS10M', 'PS', 'PRECTOTCORR', 'T2MDEW', 'ALLSKY_SFC_LW_DWN', 'WS50M_RANGE'])

# %%
df
# Out:
#                WS10M        PS  PRECTOTCORR    T2MDEW  ALLSKY_SFC_LW_DWN  \
# date
# 2019-04-01  0.388678  0.567343     0.002445  0.427349           0.373572
# 2019-04-02  0.360281  0.659906     0.002950  0.403839           0.346300
# 2019-04-03  0.330219  0.686167     0.001127  0.460821           0.407640
# 2019-04-04  0.245953  0.745970     0.000000  0.543396           0.516771
# 2019-04-05  0.257515  0.712168     0.000239  0.580825           0.539059
# ...              ...       ...          ...       ...                ...
# 2024-03-27  0.387291  0.823453     0.000000  0.556402           0.572814
# 2024-03-28  0.479512  0.758450     0.000321  0.603533           0.549868
# 2024-03-29  0.511516  0.764951     0.006726  0.612003           0.553572
# 2024-03-30  0.687725  0.756630     0.024286  0.591710           0.627955
# 2024-03-31  0.531218  0.680447     0.001342  0.486316           0.515179
#
#             WS50M_RANGE
# date
# 2019-04-01     0.490933
# 2019-04-02     0.369933
# ...

# %%
# !pip install tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
OUT_STEPS = 24
def create_dataset(data, time_steps=OUT_STEPS):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+1:i+1+time_steps])
    return np.array(X), np.array(y)

train_data, val_data = train_test_split(data, test_size=0.2, shuffle=False)

train_X, train_y = create_dataset(train_data)
val_X, val_y = create_dataset(val_data)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                WS10M        PS  PRECTOTCORR    T2MDEW  ALLSKY_SFC_LW_DWN  \
# date
# 2019-04-01  0.388678  0.567343     0.002445  0.427349           0.373572
# 2019-04-02  0.360281  0.659906     0.002950  0.403839           0.346300
# 2019-04-03  0.330219  0.686167     0.001127  0.460821           0.407640
# 2019-04-04  0.245953  0.745970     0.000000  0.543396           0.516771
# 2019-04-05  0.257515  0.712168     0.000239  0.580825           0.539059
# ...              ...       ...          ...       ...                ...
# 2024-03-27  0.387291  0.823453     0.000000  0.556402           0.572814
# 2024-03-28  0.479512  0.758450     0.000321  0.603533           0.549868
# 2024-03-29  0.511516  0.764951     0.006726  0.612003           0.553572
# 2024-03-30  0.687725  0.756630     0.024286  0.591710           0.627955
# 2024-03-31  0.531218  0.680447     0.001342  0.486316           0.515179
#
#             WS50M_RANGE  Evaporation_Rate  Sensible_Heat_Flux
# date
# ...

# %%
class FeedBack(tf.keras.Model):
    def __init__(self, units, out_steps, num_features):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = tf.keras.layers.LSTMCell(units)
        self.lstm_rnn = tf.keras.layers.RNN(self.lstm_cell, return_state=True)

        self.lstm_cell_2 = tf.keras.layers.LSTMCell(units)
        self.lstm_rnn_2 = tf.keras.layers.RNN(self.lstm_cell_2, return_state=True, return_sequences=True)

        self.dense = tf.keras.layers.Dense(num_features)

    def warmup(self, inputs):
        x, *state = self.lstm_rnn(inputs)
        x = tf.expand_dims(x, axis=1)
        x, *state_2 = self.lstm_rnn_2(x)
        x = tf.squeeze(x, axis=1)
        prediction = self.dense(x)
        return prediction, state, state_2 

    def call(self, inputs, training=None):
        predictions = []
        prediction, state, state_2 = self.warmup(inputs) 
        predictions.append(prediction)

        for n in range(1, self.out_steps):
            x = prediction
            x, state = self.lstm_cell(x, states=state, training=training)
            x, state_2 = self.lstm_cell_2(x, states=state_2, training=training)
            prediction = self.dense(x)
            predictions.append(prediction)

        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        return predictions


units = 1024  
num_features = df.shape[1]
feedback_model = FeedBack(units=units, out_steps=OUT_STEPS, num_features=num_features)

feedback_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.MeanAbsoluteError()],
    run_eagerly=True
)

# %%
# !pip install pydot graphviz
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.models import load_model

# Path to your H5 file
model_path = 'feedback_model.h5'

# Load the model
model = load_model(model_path)

# Check the model summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       4 model_path = 'feedback_model.h5'
#       6 # Load the model
# ----> 7 model = load_model(model_path)
#       9 # Check the model summary
#      10 model.summary()
#
# File c:\Users\ayush\miniconda3\envs\py310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
from tensorflow.keras.utils import plot_model

# Create a dummy input shape for visualization (batch_size, time_steps, features)
input_shape = (None, 20, df.shape[1])
feedback_model.build(input_shape)

# Visualize and save the model
plot_model(feedback_model, to_file="feedback_model.png", show_shapes=True, expand_nested=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history = feedback_model.fit(train_X, train_y, epochs=50, validation_data=(val_X, val_y), batch_size=32)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 26s 420ms/step - loss: 7175.5366 - mean_absolute_error: 32.8831 - val_loss: 5516.3345 - val_mean_absolute_error: 27.0877
# Epoch 2/50
# 45/45 [==============================] - 19s 433ms/step - loss: 4731.0776 - mean_absolute_error: 24.7118 - val_loss: 3688.8147 - val_mean_absolute_error: 21.7305
# Epoch 3/50
# 45/45 [==============================] - 19s 426ms/step - loss: 3153.5657 - mean_absolute_error: 20.0070 - val_loss: 2421.4604 - val_mean_absolute_error: 17.3885
# Epoch 4/50
# 45/45 [==============================] - 19s 430ms/step - loss: 2063.4487 - mean_absolute_error: 15.9360 - val_loss: 1566.1379 - val_mean_absolute_error: 13.6238
# Epoch 5/50
# 45/45 [==============================] - 20s 436ms/step - loss: 1338.6409 - mean_absolute_error: 12.4829 - val_loss: 1023.4755 - val_mean_absolute_error: 10.5035
# Epoch 6/50
# ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Evaluate the model on validation data
val_loss, val_mae = feedback_model.evaluate(val_X, val_y)
print(f'Validation Loss: {val_loss}, Validation MAE: {val_mae}')

# Plot some predictions
def plot_predictions(model, X, y):
    predictions = model.predict(X)
    plt.figure(figsize=(10, 6))
    plt.plot(y[0, :, 0], label='Actual')
    plt.plot(predictions[0, :, 0], label='Predicted')
    plt.legend()
    plt.show()

plot_predictions(feedback_model, val_X, val_y)
# Out:
# 11/11 [==============================] - 2s 170ms/step - loss: 348.2317 - mean_absolute_error: 6.8535
# Validation Loss: 348.2316589355469, Validation MAE: 6.853456974029541
# 11/11 [==============================] - 2s 164ms/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_path = '/content/drive/My Drive/feedback_model.h5'
feedback_model.save(model_path)

print(f"Model saved to {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to /content/drive/My Drive/feedback_model.h5
